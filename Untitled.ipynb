# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# 2022-01-19 11:47:16.746556: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/bashir/.local/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-01-19 11:47:16.746581: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
model = tf.keras.models.load_model('handwritten_digits.model')

# Load custom images and predict them
image_number = 2
while os.path.isfile('digits/digit{}.png'.format(image_number)):
    try:
        img = cv2.imread('digits/digit{}.png'.format(image_number))[:,:,0]
        img = np.invert(np.array([img]))
        prediction = model.predict(img)
        print("The number is probably a {}".format(np.argmax(prediction)))
        plt.imshow(img[0], cmap=plt.cm.binary)
        plt.show()
        image_number += 1
    except:
        print("Error reading image! Proceeding with next image...")
        image_number += 1
# Out:
# 2022-01-19 11:48:21.969062: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/bashir/.local/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-01-19 11:48:21.969111: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-01-19 11:48:21.969141: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (bashir): /proc/driver/nvidia/version does not exist
# 2022-01-19 11:48:21.969539: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# The number is probably a 2
# The number is probably a 9
# The number is probably a 8
# The number is probably a 5
# The number is probably a 6
# The number is probably a 1
# The number is probably a 1
# The number is probably a 7
# The number is probably a 7
# The number is probably a 0
# The number is probably a 1
# The number is probably a 3
# The number is probably a 2
# The number is probably a 1
# The number is probably a 0
# The number is probably a 1
# The number is probably a 7
# The number is probably a 4

# %%
img = cv2.imread('digits/digit{}.png'.format(19))[:,:,0]
img = np.invert(np.array([img]))
prediction = model.predict(img)
print("The number is probably a {}".format(np.argmax(prediction)))
plt.imshow(img[0], cmap=plt.cm.binary)
plt.show()
# image_number += 1
# Out:
# The number is probably a 4
